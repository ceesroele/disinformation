# %% [markdown]
# # Styling complex values in a dataframe
#
# This is the companion notebook of my article [Styling complex values in a dataframe](https://medium.com/p/7ebc5a17b3e7).
#
# In this notebook I show step by step how to use one value in a cell to provide the style for a second value.
#
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Background gradient
#
# Based on numbers, dataframe styles can apply a `background_gradient` based on the values in the dataframe.

# %%
# Create a 5x5 matrix of random numbers between [-0.3,0.7)
m = np.random.rand(5,5) - 0.3
df = pd.DataFrame(m)
# shading scale is determined per column
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_16023_row0_col0, #T_16023_row0_col2, #T_16023_row3_col3, #T_16023_row4_col1, #T_16023_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_16023_row0_col1 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_16023_row0_col3, #T_16023_row2_col0 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_16023_row0_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_16023_row1_col0, #T_16023_row1_col1, #T_16023_row1_col3, #T_16023_row1_col4, #T_16023_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_16023_row1_col2 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_16023_row2_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_16023_row2_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_16023_row2_col3 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_16023_row2_col4 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_16023_row3_col0 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_16023_row3_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_16023_row3_col4 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_16023_row4_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_16023_row4_col2 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_16023_row4_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# </style>
# <table id="T_16023">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16023_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_16023_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_16023_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_16023_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_16023_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16023_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16023_row0_col0" class="data row0 col0" >0.697283</td>
#       <td id="T_16023_row0_col1" class="data row0 col1" >0.206823</td>
#       <td id="T_16023_row0_col2" class="data row0 col2" >0.674626</td>
#       <td id="T_16023_row0_col3" class="data row0 col3" >0.206146</td>
#       <td id="T_16023_row0_col4" class="data row0 col4" >-0.091006</td>
#     </tr>
#     <tr>
#       <th id="T_16023_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16023_row1_col0" class="data row1 col0" >-0.126214</td>
#       <td id="T_16023_row1_col1" class="data row1 col1" >-0.275965</td>
#       <td id="T_16023_row1_col2" class="data row1 col2" >0.259420</td>
#       <td id="T_16023_row1_col3" class="data row1 col3" >-0.286650</td>
#       <td id="T_16023_row1_col4" class="data row1 col4" >-0.168661</td>
#     </tr>
#     <tr>
#       <th id="T_16023_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16023_row2_col0" class="data row2 col0" >0.533885</td>
#       <td id="T_16023_row2_col1" class="data row2 col1" >0.321333</td>
#       <td id="T_16023_row2_col2" class="data row2 col2" >0.340497</td>
#       <td id="T_16023_row2_col3" class="data row2 col3" >-0.216726</td>
#       <td id="T_16023_row2_col4" class="data row2 col4" >0.194268</td>
#     </tr>
#     <tr>
#       <th id="T_16023_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16023_row3_col0" class="data row3 col0" >0.612793</td>
#       <td id="T_16023_row3_col1" class="data row3 col1" >0.096373</td>
#       <td id="T_16023_row3_col2" class="data row3 col2" >0.109295</td>
#       <td id="T_16023_row3_col3" class="data row3 col3" >0.327023</td>
#       <td id="T_16023_row3_col4" class="data row3 col4" >0.590566</td>
#     </tr>
#     <tr>
#       <th id="T_16023_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16023_row4_col0" class="data row4 col0" >0.033498</td>
#       <td id="T_16023_row4_col1" class="data row4 col1" >0.653014</td>
#       <td id="T_16023_row4_col2" class="data row4 col2" >0.524113</td>
#       <td id="T_16023_row4_col3" class="data row4 col3" >-0.139900</td>
#       <td id="T_16023_row4_col4" class="data row4 col4" >0.624393</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Applying any function to a cell
#
# Next, we apply a method to each cell in the dataframe using `applymap`. We color all negative numbers red.

# %%
def style_negative(v, props=''):
    return props if v < 0 else None

df.style.applymap(style_negative, props='color:red;')
# Out:
# <style type="text/css">
# #T_7c080_row0_col4, #T_7c080_row1_col0, #T_7c080_row1_col1, #T_7c080_row1_col3, #T_7c080_row1_col4, #T_7c080_row2_col3, #T_7c080_row4_col3 {
#   color: red;
# }
# </style>
# <table id="T_7c080">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c080_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7c080_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7c080_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_7c080_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_7c080_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c080_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c080_row0_col0" class="data row0 col0" >0.697283</td>
#       <td id="T_7c080_row0_col1" class="data row0 col1" >0.206823</td>
#       <td id="T_7c080_row0_col2" class="data row0 col2" >0.674626</td>
#       <td id="T_7c080_row0_col3" class="data row0 col3" >0.206146</td>
#       <td id="T_7c080_row0_col4" class="data row0 col4" >-0.091006</td>
#     </tr>
#     <tr>
#       <th id="T_7c080_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c080_row1_col0" class="data row1 col0" >-0.126214</td>
#       <td id="T_7c080_row1_col1" class="data row1 col1" >-0.275965</td>
#       <td id="T_7c080_row1_col2" class="data row1 col2" >0.259420</td>
#       <td id="T_7c080_row1_col3" class="data row1 col3" >-0.286650</td>
#       <td id="T_7c080_row1_col4" class="data row1 col4" >-0.168661</td>
#     </tr>
#     <tr>
#       <th id="T_7c080_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c080_row2_col0" class="data row2 col0" >0.533885</td>
#       <td id="T_7c080_row2_col1" class="data row2 col1" >0.321333</td>
#       <td id="T_7c080_row2_col2" class="data row2 col2" >0.340497</td>
#       <td id="T_7c080_row2_col3" class="data row2 col3" >-0.216726</td>
#       <td id="T_7c080_row2_col4" class="data row2 col4" >0.194268</td>
#     </tr>
#     <tr>
#       <th id="T_7c080_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c080_row3_col0" class="data row3 col0" >0.612793</td>
#       <td id="T_7c080_row3_col1" class="data row3 col1" >0.096373</td>
#       <td id="T_7c080_row3_col2" class="data row3 col2" >0.109295</td>
#       <td id="T_7c080_row3_col3" class="data row3 col3" >0.327023</td>
#       <td id="T_7c080_row3_col4" class="data row3 col4" >0.590566</td>
#     </tr>
#     <tr>
#       <th id="T_7c080_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c080_row4_col0" class="data row4 col0" >0.033498</td>
#       <td id="T_7c080_row4_col1" class="data row4 col1" >0.653014</td>
#       <td id="T_7c080_row4_col2" class="data row4 col2" >0.524113</td>
#       <td id="T_7c080_row4_col3" class="data row4 col3" >-0.139900</td>
#       <td id="T_7c080_row4_col4" class="data row4 col4" >0.624393</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Complex values
#
# Pandas documentation on (applying styles to tables)[https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html] is limited to discussing how the actual values in a dataframe are to be stylised.
#
# But what if we have complex values in our dataframe, tuples, where one element is to be displayed and the other is to determine the stylisation?

# %%
import re
# "A Visit from St. Nicholas" by Clement Clarke Moore
# https://www.poetryfoundation.org/poems/43171/a-visit-from-st-nicholas
poem = """
'Twas the night before Christmas, when all through the house
Not a creature was stirring, not even a mouse;
The stockings were hung by the chimney with care,
In hopes that St. Nicholas soon would be there;
"""

words = re.split(r'\W+', poem)
pairs = [(x, len(x)) for x in words]
# Create a 5x5 matrix of tuples: (word, length)
matrix = []
for i in range(0,5):
    matrix.append(pairs[5*i:5*(i+1)])
df2 = pd.DataFrame(matrix)
df2
# Out:
#                 0               1          2              3            4
# 0           (, 0)       (Twas, 4)   (the, 3)     (night, 5)  (before, 6)
# 1  (Christmas, 9)       (when, 4)   (all, 3)   (through, 7)     (the, 3)
# 2      (house, 5)        (Not, 3)     (a, 1)  (creature, 8)     (was, 3)
# 3   (stirring, 8)        (not, 3)  (even, 4)         (a, 1)   (mouse, 5)
# 4        (The, 3)  (stockings, 9)  (were, 4)      (hung, 4)      (by, 2)

# %% [markdown]
# ### Displaying values
#
# To display values we use the `format` method. If the argument to `format` is a callable, then that will be used to convert the value of the cell to what is to be displayed. Here we just want the first element of the tuple in the cell, which is the word.
#
# See: https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.format.html

# %%
df2.style.format(lambda x: x[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_2da8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2da8d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2da8d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2da8d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2da8d_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2da8d_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2da8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2da8d_row0_col0" class="data row0 col0" ></td>
#       <td id="T_2da8d_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_2da8d_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_2da8d_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_2da8d_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_2da8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2da8d_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_2da8d_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_2da8d_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_2da8d_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_2da8d_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_2da8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2da8d_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_2da8d_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_2da8d_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_2da8d_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_2da8d_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_2da8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2da8d_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_2da8d_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_2da8d_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_2da8d_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_2da8d_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_2da8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2da8d_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_2da8d_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_2da8d_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_2da8d_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_2da8d_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Applying styles to values
#
# We can apply a CSS-styling function to an element by using a style's `applymap` method. Here we use a simple method to determine what colour background is to be used.
#
# See: https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.applymap.html

# %%
def font_short(v, weight, color):
    """
    Mark short words
    
    Parameters
    ----------
    v: tuple of (word, length)
    weight: CSS term accepted as a font-weight value
    color: CSS term accepted as a color
    """
    return f"font-weight: {weight}; color: {color}" if v[1] < 4 else None

# We must apply both `format` and `applymap` to the DataFrame.style
styler = df2.style.format(lambda x: x[0])
styler.applymap(font_short, weight='bold', color='orange')
# Out:
# <style type="text/css">
# #T_1e44c_row0_col0, #T_1e44c_row0_col2, #T_1e44c_row1_col2, #T_1e44c_row1_col4, #T_1e44c_row2_col1, #T_1e44c_row2_col2, #T_1e44c_row2_col4, #T_1e44c_row3_col1, #T_1e44c_row3_col3, #T_1e44c_row4_col0, #T_1e44c_row4_col4 {
#   font-weight: bold;
#   color: orange;
# }
# </style>
# <table id="T_1e44c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e44c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1e44c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1e44c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_1e44c_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_1e44c_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e44c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e44c_row0_col0" class="data row0 col0" ></td>
#       <td id="T_1e44c_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_1e44c_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_1e44c_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_1e44c_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_1e44c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e44c_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_1e44c_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_1e44c_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_1e44c_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_1e44c_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_1e44c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e44c_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_1e44c_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_1e44c_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_1e44c_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_1e44c_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_1e44c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e44c_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_1e44c_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_1e44c_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_1e44c_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_1e44c_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_1e44c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e44c_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_1e44c_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_1e44c_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_1e44c_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_1e44c_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Using a gradient to represent word lengths
#
# Next, let's represent the length of words as a gradient. Long words become dark, short words light. To do this, we must convert the length of the word to a fraction between 0 and 1, relative to the length of the shortest word and the length of the longest word.
#
# We use matplotlib to convert that fraction to a hexadecimal term which we then use to define the background colour in CSS.

# %%
import matplotlib as mpl
def make_gradient(v, min_length, max_length, cmap='YlGn'):
    """
    Parameters
    ----------
    
    v: tuple of (word, length)
    min_length: int 
        minimum length of all words in the matrix
    max_length: int
        maximum length of all words in the matrix
    cmap: matplotlib color map, default value here is 'YlGn'
        
    Returns
    -------
    
    string:
        CSS setting a colour
              
    For Matplotlib colormaps:
    See: https://matplotlib.org/stable/tutorials/colors/colormaps.html

    """
    # normalize the word length as a fraction of the range between min_length and max_length
    rel_v = (v[1] - min_length) / (max_length - min_length)
    # define the colormap
    cmap = mpl.cm.get_cmap(cmap)
    # Get a colour out of the given colormap based on a value [0,1]
    rgba = cmap(rel_v)  
    # convert the colour to a hexadecimal string representation
    return f'background-color: {mpl.colors.rgb2hex(rgba)};'

# We must apply both `format` and `applymap` to the DataFrame.style
styler = df2.style.format(lambda x: x[0])
min_length = min([x[1] for x in pairs])
max_length = max([x[1] for x in pairs])
styler.applymap(lambda x: make_gradient(x, min_length, max_length))
# Out:
# <style type="text/css">
# #T_5af41_row0_col0 {
#   background-color: #ffffe5;
# }
# #T_5af41_row0_col1, #T_5af41_row1_col1, #T_5af41_row3_col2, #T_5af41_row4_col2, #T_5af41_row4_col3 {
#   background-color: #90d083;
# }
# #T_5af41_row0_col2, #T_5af41_row1_col2, #T_5af41_row1_col4, #T_5af41_row2_col1, #T_5af41_row2_col4, #T_5af41_row3_col1, #T_5af41_row4_col0 {
#   background-color: #bce395;
# }
# #T_5af41_row0_col3, #T_5af41_row2_col0, #T_5af41_row3_col4 {
#   background-color: #5fba6c;
# }
# #T_5af41_row0_col4 {
#   background-color: #379e54;
# }
# #T_5af41_row1_col0, #T_5af41_row4_col1 {
#   background-color: #004529;
# }
# #T_5af41_row1_col3 {
#   background-color: #1a7d40;
# }
# #T_5af41_row2_col2, #T_5af41_row3_col3 {
#   background-color: #f8fcbe;
# }
# #T_5af41_row2_col3, #T_5af41_row3_col0 {
#   background-color: #006435;
# }
# #T_5af41_row4_col4 {
#   background-color: #e0f3a8;
# }
# </style>
# <table id="T_5af41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5af41_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5af41_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_5af41_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_5af41_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_5af41_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5af41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5af41_row0_col0" class="data row0 col0" ></td>
#       <td id="T_5af41_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_5af41_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_5af41_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_5af41_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_5af41_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5af41_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_5af41_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_5af41_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_5af41_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_5af41_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_5af41_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5af41_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_5af41_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_5af41_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_5af41_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_5af41_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_5af41_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5af41_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_5af41_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_5af41_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_5af41_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_5af41_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_5af41_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5af41_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_5af41_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_5af41_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_5af41_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_5af41_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_lengths = df2.applymap(lambda x: x[1])
df_words = df2.applymap(lambda x: x[0])
df_words.style.background_gradient(gmap=df_lengths, axis=None)
# Out:
# <style type="text/css">
# #T_14047_row0_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_14047_row0_col1, #T_14047_row1_col1, #T_14047_row3_col2, #T_14047_row4_col2, #T_14047_row4_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_14047_row0_col2, #T_14047_row1_col2, #T_14047_row1_col4, #T_14047_row2_col1, #T_14047_row2_col4, #T_14047_row3_col1, #T_14047_row4_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_14047_row0_col3, #T_14047_row2_col0, #T_14047_row3_col4 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_14047_row0_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_14047_row1_col0, #T_14047_row4_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_14047_row1_col3 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_14047_row2_col2, #T_14047_row3_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_14047_row2_col3, #T_14047_row3_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_14047_row4_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# </style>
# <table id="T_14047">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14047_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_14047_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_14047_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_14047_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_14047_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14047_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14047_row0_col0" class="data row0 col0" ></td>
#       <td id="T_14047_row0_col1" class="data row0 col1" >Twas</td>
#       <td id="T_14047_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_14047_row0_col3" class="data row0 col3" >night</td>
#       <td id="T_14047_row0_col4" class="data row0 col4" >before</td>
#     </tr>
#     <tr>
#       <th id="T_14047_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14047_row1_col0" class="data row1 col0" >Christmas</td>
#       <td id="T_14047_row1_col1" class="data row1 col1" >when</td>
#       <td id="T_14047_row1_col2" class="data row1 col2" >all</td>
#       <td id="T_14047_row1_col3" class="data row1 col3" >through</td>
#       <td id="T_14047_row1_col4" class="data row1 col4" >the</td>
#     </tr>
#     <tr>
#       <th id="T_14047_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14047_row2_col0" class="data row2 col0" >house</td>
#       <td id="T_14047_row2_col1" class="data row2 col1" >Not</td>
#       <td id="T_14047_row2_col2" class="data row2 col2" >a</td>
#       <td id="T_14047_row2_col3" class="data row2 col3" >creature</td>
#       <td id="T_14047_row2_col4" class="data row2 col4" >was</td>
#     </tr>
#     <tr>
#       <th id="T_14047_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14047_row3_col0" class="data row3 col0" >stirring</td>
#       <td id="T_14047_row3_col1" class="data row3 col1" >not</td>
#       <td id="T_14047_row3_col2" class="data row3 col2" >even</td>
#       <td id="T_14047_row3_col3" class="data row3 col3" >a</td>
#       <td id="T_14047_row3_col4" class="data row3 col4" >mouse</td>
#     </tr>
#     <tr>
#       <th id="T_14047_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14047_row4_col0" class="data row4 col0" >The</td>
#       <td id="T_14047_row4_col1" class="data row4 col1" >stockings</td>
#       <td id="T_14047_row4_col2" class="data row4 col2" >were</td>
#       <td id="T_14047_row4_col3" class="data row4 col3" >hung</td>
#       <td id="T_14047_row4_col4" class="data row4 col4" >by</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now, that was easy! We don't even need to bother with a matrix with tuples to create this background gradient!

# %% [markdown]
# ### And now with tooltips
#
# So, let's add another functional requirement: colours are nice, but we want to be able to see the exact original word lengths in a tooltip. Let's go back to our matrix of tuples.
#
# We will use the Styler's `set_tooltips` method, which takes as arguments a dataframe and a list of properties. The dataframe should correspond to the dataframe which we want to provide tooltips for, just as df_lengths corresponds to df_words.
#
# We will convert `df_lengths` to a dataframe containing the tooltips for all cells.

# %%
df_tooltips = df_lengths.applymap(lambda x: f'length: {x}')
df_tooltips
# Out:
#            0          1          2          3          4
# 0  length: 0  length: 4  length: 3  length: 5  length: 6
# 1  length: 9  length: 4  length: 3  length: 7  length: 3
# 2  length: 5  length: 3  length: 1  length: 8  length: 3
# 3  length: 8  length: 3  length: 4  length: 1  length: 5
# 4  length: 3  length: 9  length: 4  length: 4  length: 2

# %% [markdown]
# Now we will both apply the gradient using `df_lengths` and the tooltips using `df_tooltips`.

# %%
df_lengths = df2.applymap(lambda x: x[1])
df_words = df2.applymap(lambda x: x[0])
styler = df_words.style.background_gradient(gmap=df_lengths, axis=None, cmap='YlOrRd')
styler.set_tooltips(
    df_lengths.applymap(lambda x: f'length: {x}'),
    props=[
        ('visibility', 'hidden'),
        ('position', 'absolute'),
        ('background-color', 'white'),
        ('color', 'black'),
        ('z-index', 1),
        ('padding', '3px 3px'),
        ('margin', '2px')
    ])
# Out:
# <style type="text/css">
# #T_a5e58 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   background-color: white;
#   color: black;
#   z-index: 1;
#   padding: 3px 3px;
#   margin: 2px;
# }
# #T_a5e58 #T_a5e58_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row0_col0 .pd-t::after {
#   content: "length: 0";
# }
# #T_a5e58 #T_a5e58_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row0_col1 .pd-t::after {
#   content: "length: 4";
# }
# #T_a5e58 #T_a5e58_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row0_col2 .pd-t::after {
#   content: "length: 3";
# }
# #T_a5e58 #T_a5e58_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row0_col3 .pd-t::after {
#   content: "length: 5";
# }
# #T_a5e58 #T_a5e58_row0_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row0_col4 .pd-t::after {
#   content: "length: 6";
# }
# #T_a5e58 #T_a5e58_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row1_col0 .pd-t::after {
#   content: "length: 9";
# }
# #T_a5e58 #T_a5e58_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row1_col1 .pd-t::after {
#   content: "length: 4";
# }
# #T_a5e58 #T_a5e58_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row1_col2 .pd-t::after {
#   content: "length: 3";
# }
# #T_a5e58 #T_a5e58_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row1_col3 .pd-t::after {
#   content: "length: 7";
# }
# #T_a5e58 #T_a5e58_row1_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row1_col4 .pd-t::after {
#   content: "length: 3";
# }
# #T_a5e58 #T_a5e58_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row2_col0 .pd-t::after {
#   content: "length: 5";
# }
# #T_a5e58 #T_a5e58_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row2_col1 .pd-t::after {
#   content: "length: 3";
# }
# #T_a5e58 #T_a5e58_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row2_col2 .pd-t::after {
#   content: "length: 1";
# }
# #T_a5e58 #T_a5e58_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row2_col3 .pd-t::after {
#   content: "length: 8";
# }
# #T_a5e58 #T_a5e58_row2_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row2_col4 .pd-t::after {
#   content: "length: 3";
# }
# #T_a5e58 #T_a5e58_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row3_col0 .pd-t::after {
#   content: "length: 8";
# }
# #T_a5e58 #T_a5e58_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row3_col1 .pd-t::after {
#   content: "length: 3";
# }
# #T_a5e58 #T_a5e58_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row3_col2 .pd-t::after {
#   content: "length: 4";
# }
# #T_a5e58 #T_a5e58_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row3_col3 .pd-t::after {
#   content: "length: 1";
# }
# #T_a5e58 #T_a5e58_row3_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row3_col4 .pd-t::after {
#   content: "length: 5";
# }
# #T_a5e58 #T_a5e58_row4_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row4_col0 .pd-t::after {
#   content: "length: 3";
# }
# #T_a5e58 #T_a5e58_row4_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row4_col1 .pd-t::after {
#   content: "length: 9";
# }
# #T_a5e58 #T_a5e58_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row4_col2 .pd-t::after {
#   content: "length: 4";
# }
# #T_a5e58 #T_a5e58_row4_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row4_col3 .pd-t::after {
#   content: "length: 4";
# }
# #T_a5e58 #T_a5e58_row4_col4:hover .pd-t {
#   visibility: visible;
# }
# #T_a5e58 #T_a5e58_row4_col4 .pd-t::after {
#   content: "length: 2";
# }
# #T_a5e58_row0_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_a5e58_row0_col1, #T_a5e58_row1_col1, #T_a5e58_row3_col2, #T_a5e58_row4_col2, #T_a5e58_row4_col3 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_a5e58_row0_col2, #T_a5e58_row1_col2, #T_a5e58_row1_col4, #T_a5e58_row2_col1, #T_a5e58_row2_col4, #T_a5e58_row3_col1, #T_a5e58_row4_col0 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_a5e58_row0_col3, #T_a5e58_row2_col0, #T_a5e58_row3_col4 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_a5e58_row0_col4 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_a5e58_row1_col0, #T_a5e58_row4_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_a5e58_row1_col3 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_a5e58_row2_col2, #T_a5e58_row3_col3 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_a5e58_row2_col3, #T_a5e58_row3_col0 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_a5e58_row4_col4 {
#   background-color: #fede80;
#   color: #000000;
# }
# </style>
# <table id="T_a5e58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5e58_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a5e58_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a5e58_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a5e58_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_a5e58_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5e58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5e58_row0_col0" class="data row0 col0" ><span class="pd-t"></span></td>
#       <td id="T_a5e58_row0_col1" class="data row0 col1" >Twas<span class="pd-t"></span></td>
#       <td id="T_a5e58_row0_col2" class="data row0 col2" >the<span class="pd-t"></span></td>
#       <td id="T_a5e58_row0_col3" class="data row0 col3" >night<span class="pd-t"></span></td>
#       <td id="T_a5e58_row0_col4" class="data row0 col4" >before<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_a5e58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5e58_row1_col0" class="data row1 col0" >Christmas<span class="pd-t"></span></td>
#       <td id="T_a5e58_row1_col1" class="data row1 col1" >when<span class="pd-t"></span></td>
#       <td id="T_a5e58_row1_col2" class="data row1 col2" >all<span class="pd-t"></span></td>
#       <td id="T_a5e58_row1_col3" class="data row1 col3" >through<span class="pd-t"></span></td>
#       <td id="T_a5e58_row1_col4" class="data row1 col4" >the<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_a5e58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5e58_row2_col0" class="data row2 col0" >house<span class="pd-t"></span></td>
#       <td id="T_a5e58_row2_col1" class="data row2 col1" >Not<span class="pd-t"></span></td>
#       <td id="T_a5e58_row2_col2" class="data row2 col2" >a<span class="pd-t"></span></td>
#       <td id="T_a5e58_row2_col3" class="data row2 col3" >creature<span class="pd-t"></span></td>
#       <td id="T_a5e58_row2_col4" class="data row2 col4" >was<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_a5e58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5e58_row3_col0" class="data row3 col0" >stirring<span class="pd-t"></span></td>
#       <td id="T_a5e58_row3_col1" class="data row3 col1" >not<span class="pd-t"></span></td>
#       <td id="T_a5e58_row3_col2" class="data row3 col2" >even<span class="pd-t"></span></td>
#       <td id="T_a5e58_row3_col3" class="data row3 col3" >a<span class="pd-t"></span></td>
#       <td id="T_a5e58_row3_col4" class="data row3 col4" >mouse<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_a5e58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5e58_row4_col0" class="data row4 col0" >The<span class="pd-t"></span></td>
#       <td id="T_a5e58_row4_col1" class="data row4 col1" >stockings<span class="pd-t"></span></td>
#       <td id="T_a5e58_row4_col2" class="data row4 col2" >were<span class="pd-t"></span></td>
#       <td id="T_a5e58_row4_col3" class="data row4 col3" >hung<span class="pd-t"></span></td>
#       <td id="T_a5e58_row4_col4" class="data row4 col4" >by<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>
